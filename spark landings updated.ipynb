# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.remote("sc://localhost").getOrCreate()
spark

# %%
import os

os.getcwd()
# Out:
# '/home/analytics4220/Melissa_Suda_Holtmann'

# %%
df = spark.read.csv("/home/analytics4220/Melissa_Suda_Holtmann/Meteorite_Landings.csv", 
                    header=True, quote='"')
df
# Out:
# DataFrame[name: string, id: string, nametype: string, recclass: string, mass (g): string, fall: string, year: string, reclat: string, reclong: string, GeoLocation: string]

# %% [markdown]
# Let's see what the table looks like.

# %%
df.show()
# Out:
# +-------------------+---+--------+------------+--------+----+----+----------+-----------+--------------------+
# |               name| id|nametype|    recclass|mass (g)|fall|year|    reclat|    reclong|         GeoLocation|
# +-------------------+---+--------+------------+--------+----+----+----------+-----------+--------------------+
# |             Aachen|  1|   Valid|          L5|      21|Fell|1880| 50.775000|   6.083330|   (50.775, 6.08333)|
# |             Aarhus|  2|   Valid|          H6|     720|Fell|1951| 56.183330|  10.233330|(56.18333, 10.23333)|
# |               Abee|  6|   Valid|         EH4|  107000|Fell|1952| 54.216670|-113.000000|  (54.21667, -113.0)|
# |           Acapulco| 10|   Valid| Acapulcoite|    1914|Fell|1976| 16.883330| -99.900000|   (16.88333, -99.9)|
# |            Achiras|370|   Valid|          L6|     780|Fell|1902|-33.166670| -64.950000| (-33.16667, -64.95)|
# |           Adhi Kot|379|   Valid|         EH4|    4239|Fell|1919| 32.100000|  71.800000|        (32.1, 71.8)|
# |Adzhi-Bogdo (stone)|390|   Valid|       LL3-6|     910|Fell|1949| 44.833330|  95.166670|(44.83333, 95.16667)|
# |               Agen|392|   Valid|          H5|   30000|Fell|1814| 44.216670|   0.616670| (44.21667, 0.61667)|
# |             Aguada|398|   Valid|          L6|    1620|Fell|1930|-31.600000| -65.233330|  (-31.6, -65.23333)|
# |      Aguila Blanca|417|   Valid|           L|    1440|Fell|1920|-30.866670| -64.550000| (-30.86667, -64.55)|
# |   Aioun el Atrouss|423|   Valid|Diogenite-pm|    1000|Fell|1974| 16.398060|  -9.570280|(16.39806, -9.57028)|
# |                Aïr|424|   Valid|          L6|   24000|Fell|1925| 19.083330|   8.383330| (19.08333, 8.38333)|
# |    Aire-sur-la-Lys|425|   Valid|     Unknown|    NULL|Fell|1769| 50.666670|   2.333330| (50.66667, 2.33333)|
# |              Akaba|426|   Valid|          L6|     779|Fell|1949| 29.516670|  35.050000|   (29.51667, 35.05)|
# |           Akbarpur|427|   Valid|          H4|    1800|Fell|1838| 29.716670|  77.950000|   (29.71667, 77.95)|
# |            Akwanga|432|   Valid|           H|    3000|Fell|1959|  8.916670|   8.433330|  (8.91667, 8.43333)|
# |            Akyumak|433|   Valid|   Iron, IVA|   50000|Fell|1981| 39.916670|  42.816670|(39.91667, 42.81667)|
# |            Al Rais|446|   Valid|      CR2-an|     160|Fell|1957| 24.416670|  39.516670|(24.41667, 39.51667)|
# |          Al Zarnkh|447|   Valid|         LL5|     700|Fell|2001| 13.660330|  28.960000|   (13.66033, 28.96)|
# |              Alais|448|   Valid|         CI1|    6000|Fell|1806| 44.116670|   4.083330| (44.11667, 4.08333)|
# +-------------------+---+--------+------------+--------+----+----+----------+-----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# My Hypothesis is that meteorites are predominantily high iron.
#
# The name convention of the meteorite content (looking at iron) you will see letters (H=High, L=Low, LL=very low, for how much iron there is) followed by a numbers 1-6 represents that numbers represent how much the material was changed by heat.
#
# Then the Iron and Nickle combinations are represented with the word Iron in them

# %%
df.printSchema()
# Out:
# root
#  |-- name: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- nametype: string (nullable = true)
#  |-- recclass: string (nullable = true)
#  |-- mass (g): string (nullable = true)
#  |-- fall: string (nullable = true)
#  |-- year: string (nullable = true)
#  |-- reclat: string (nullable = true)
#  |-- reclong: string (nullable = true)
#  |-- GeoLocation: string (nullable = true)

# %%
high_iron= df.filter(
    (df["recclass"].startswith("H")) | 
    (df["recclass"].contains("Iron"))
)
high_iron.show()
# Out:
# +-------------+----+--------+----------+--------+----+----+----------+-----------+--------------------+
# |         name|  id|nametype|  recclass|mass (g)|fall|year|    reclat|    reclong|         GeoLocation|
# +-------------+----+--------+----------+--------+----+----+----------+-----------+--------------------+
# |       Aarhus|   2|   Valid|        H6|     720|Fell|1951| 56.183330|  10.233330|(56.18333, 10.23333)|
# |         Agen| 392|   Valid|        H5|   30000|Fell|1814| 44.216670|   0.616670| (44.21667, 0.61667)|
# |     Akbarpur| 427|   Valid|        H4|    1800|Fell|1838| 29.716670|  77.950000|   (29.71667, 77.95)|
# |      Akwanga| 432|   Valid|         H|    3000|Fell|1959|  8.916670|   8.433330|  (8.91667, 8.43333)|
# |      Akyumak| 433|   Valid| Iron, IVA|   50000|Fell|1981| 39.916670|  42.816670|(39.91667, 42.81667)|
# |  Alessandria| 463|   Valid|        H5|     908|Fell|1860| 44.883330|   8.750000|    (44.88333, 8.75)|
# |Alexandrovsky| 465|   Valid|        H4|    9251|Fell|1900| 50.950000|  31.816670|   (50.95, 31.81667)|
# |      Allegan|2276|   Valid|        H5|   32000|Fell|1899| 42.533330| -85.883330|(42.53333, -85.88...|
# |Ambapur Nagla|2290|   Valid|        H5|    6400|Fell|1895| 27.666670|  78.250000|   (27.66667, 78.25)|
# |       Andura|2298|   Valid|        H6|   17900|Fell|1939| 20.883330|  76.866670|(20.88333, 76.86667)|
# |      Ankober|2304|   Valid|        H4|    6500|Fell|1942|  9.533330|  39.716670| (9.53333, 39.71667)|
# |       Anlong|2305|   Valid|        H5|    2500|Fell|1971| 25.150000| 105.183330|  (25.15, 105.18333)|
# |   Arbol Solo|2325|   Valid|        H5|     810|Fell|1954|-33.000000| -66.000000|      (-33.0, -66.0)|
# |       Archie|2329|   Valid|        H6|    5070|Fell|1932| 38.500000| -94.300000|       (38.5, -94.3)|
# |Arroyo Aguiar|2340|   Valid|        H5|    7450|Fell|1950|-31.416670| -60.666670|(-31.41667, -60.6...|
# |         Asco|2345|   Valid|        H6|      41|Fell|1805| 42.450000|   9.033330|    (42.45, 9.03333)|
# |       Assisi|2353|   Valid|        H5|    2000|Fell|1886| 43.033330|  12.550000|   (43.03333, 12.55)|
# |  Avanhandava|4905|   Valid|        H4|    9330|Fell|1952|-21.460280| -49.950830|(-21.46028, -49.9...|
# |         Avce|4906|   Valid|Iron, IIAB|    1230|Fell|1908| 46.000000|  13.500000|        (46.0, 13.5)|
# |       Avilez|4907|   Valid|         H|     146|Fell|1855| 25.000000|-103.500000|      (25.0, -103.5)|
# +-------------+----+--------+----------+--------+----+----+----------+-----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# that filter is not very good because it loses some of the information that we are looking for when H is not the first chater let's take a deeper look at the veriables aviable

# %%
type_df = df.groupBy("recclass").count()
type_df.show(800)
# Out:
# +--------------------+-----+
# |            recclass|count|
# +--------------------+-----+
# |               H5-an|    2|
# |              H3.7-5|    2|
# |                   K|    1|
# |           Howardite|  240|
# |                 CM2|  416|
# |                  C6|    2|
# |                 OC3|    8|
# |               CK3.8|    1|
# |                EL6 |    1|
# |      Enst achon-ung|    3|
# |                 CK4|   75|
# |        L4-melt rock|    1|
# |              H3.7-6|    1|
# |           Iron, IVB|   14|
# |               CO3.0|    4|
# |     Mesosiderite-A4|    3|
# |                  H6| 4528|
# |            L3.5-3.7|    1|
# |            L3.3-3.7|    1|
# |             Martian|    1|
# |            Ureilite|  300|
# |            Iron, IC|   10|
# |               EL6/7|    2|
# |                  R6|    9|
# |              LL3.10|    3|
# |       Eucrite-mmict|  108|
# |                L3-6|   32|
# |      Lunar (anorth)|   69|
# |                 L6 |   54|
# |               LL3.2|   14|
# |         Iron, IC-an|    2|
# |              LL<3.5|    1|
# |          Stone-uncl|   50|
# |     Iron, ungrouped|  113|
# |               H3-an|    1|
# |            C1/2-ung|    1|
# |              LL6-an|    1|
# |        Diogenite-pm|   11|
# |                L3.4|   51|
# |        Iron, IAB-an|    3|
# |               CO3.4|    5|
# |                CH3 |    1|
# |              L3.7-4|    1|
# |             LL3.9/4|    1|
# |             Eucrite|  221|
# |              C4-ung|    3|
# |         Relict iron|    1|
# |        EL-melt rock|    2|
# |              H/L3.7|    1|
# |                 EH4|   18|
# |               E5-an|    1|
# |               EH4/5|    9|
# |                L3.1|   13|
# |        Howardite-an|    1|
# |              H3.8-4|    1|
# |              H3.8-6|    2|
# |               EL4/5|    1|
# |          Aubrite-an|    6|
# |             L(LL)~4|    1|
# |            L3.4-3.7|    1|
# |      Lunar (gabbro)|    6|
# |               H3.15|    1|
# |                L3-4|    4|
# |       Iron, IAB-sLH|    9|
# |                R4/5|    1|
# |              H3.9-5|    2|
# |              H3.5-4|    1|
# |          Eucrite-an|    3|
# |    Lunar (bas/anor)|    2|
# |                L5-7|    1|
# |                H3-5|   39|
# |                  H3|  386|
# |                H3/4|   35|
# |                 L~3|    1|
# |      Lunar (norite)|    1|
# |              H3.4-5|    1|
# |               CO3.5|   12|
# |               H(L)3|    2|
# |Martian (shergott...|   99|
# |               CM1/2|   18|
# |           Iron, IIG|    6|
# |                 EH3|  120|
# |                 L~6|   94|
# |              R3.8-6|    4|
# |              H3.8/4|    2|
# |              CV3-an|    4|
# |               H~4/5|    3|
# |              LL3.15|    3|
# |              H3.9/4|    5|
# |               L3.00|    1|
# |                H5/6|  193|
# |                  E4|    4|
# |      Ureilite-pmict|   23|
# | Impact melt breccia|    1|
# |               LL3.7|   26|
# |              C1-ung|    1|
# |              LL3.05|    1|
# |           Stone-ung|    1|
# |                  K3|    2|
# |     Mesosiderite-C2|    2|
# |               CO3.6|    7|
# |                 LL3|  128|
# |              H3.6-6|    2|
# |               CM-an|    2|
# |                   E|    7|
# |          L-imp melt|   25|
# |     LL-melt breccia|   54|
# |                H4-5|   47|
# |                H/L3|    6|
# |               LL3-5|    2|
# |          Iron, IIE?|    1|
# |                  LL|  225|
# |                 H~6|   22|
# |            H3.4/3.5|    1|
# |                L5/6|  109|
# |               LL3.6|   17|
# |                C4/5|    1|
# |                 H5 |   22|
# |             L/LL4/5|    1|
# |      L/LL-melt rock|    1|
# |               LL3.5|   17|
# |             L/LL4-6|    1|
# |    LL6-melt breccia|    2|
# |      Achondrite-ung|   57|
# |          Brachinite|   33|
# |              H/L3.9|    1|
# |              R3.8-5|    1|
# |              L/LL~5|    2|
# |              LL(L)3|    7|
# |               CO3.3|    7|
# |        Iron, IIE-an|    7|
# |               LL5-6|   40|
# |                  R3|   15|
# |       Mesosiderite?|    1|
# |           L(LL)3.05|    2|
# |               H3.05|    2|
# |               CK3/4|    1|
# |            H3.2-3.7|    1|
# |               LL3.8|   28|
# |              LL~4/5|    1|
# |     L4-melt breccia|    1|
# |                  C4|    2|
# |               CO3.1|    6|
# |             Aubrite|   63|
# |           Iron, IID|   19|
# |     Mesosiderite-A2|    3|
# |   Diogenite-olivine|    9|
# |                 CBa|    5|
# |                L3-5|   13|
# |                L3.5|   88|
# |               LL3/4|    1|
# |                H3-6|   43|
# |                LL6 |    2|
# |                H4/6|    6|
# |                L3.2|   15|
# |             H-metal|    6|
# |           Iron, IIC|    8|
# |Pallasite, ungrouped|    5|
# |              L3.9-5|    1|
# |                 H6 |    1|
# |              CH/CBb|    1|
# |             L/LL3-6|    1|
# |               L3.05|    2|
# |            LL(L)3.1|    1|
# |                   L|   50|
# |               LL3.0|    4|
# |                R3-6|   10|
# |                Iron|   94|
# |            L3.2-3.6|    1|
# |              L3.5-5|    1|
# |       Iron, IAB-sHH|    5|
# |Lunar (bas. breccia)|    2|
# |                  H7|   12|
# |        Eucrite-unbr|   32|
# |                H3.5|   18|
# |        Iron, IID-an|    2|
# |          Iron, IIIF|    9|
# |                 EH5|    6|
# |              H/L3.6|    1|
# |              H3.2-6|    1|
# |             Unknown|    7|
# |                H3-4|   10|
# |            C3.0-ung|    1|
# |      L-melt breccia|   14|
# |            H3.7/3.8|    1|
# |            Relict H|    1|
# |      H-melt breccia|    4|
# |     Mesosiderite-A1|    6|
# |               L3.10|    1|
# |              L3.6-4|    1|
# |  Martian (nakhlite)|   14|
# |Chondrite-fusion ...|    4|
# |                 CR7|    1|
# |          Eucrite-cm|   26|
# |           Relict OC|   65|
# |              CM2-an|    1|
# |         Iron, IIIAB|  285|
# |              L/LL~6|    3|
# |                 CR1|    2|
# |                H4-6|   67|
# |           Winonaite|   25|
# |            L/LL6-an|    1|
# |         H-melt rock|    8|
# |                H6/7|    2|
# |                  CR|    8|
# |                H3.0|    3|
# |                L3/4|   12|
# |                 LL4|  268|
# |                L3.8|   66|
# |                 EL3|   19|
# |                LL~6|    5|
# |               LL5-7|    1|
# |                   C|    8|
# |                 LL7|   22|
# |                R3.6|    3|
# |         LL-imp melt|    2|
# |              H/L4/5|    1|
# |     Mesosiderite-A3|    3|
# |               CO3.7|    1|
# |                 CK6|   17|
# |                  L7|   21|
# |    Iron, IAB-sHL-an|    1|
# |     L5-melt breccia|    3|
# |             L/LL3.5|    1|
# |                L/LL|    1|
# |               LL3.4|   20|
# |       Iron, IAB-ung|   46|
# |          Eucrite-br|   80|
# |     H5-melt breccia|    4|
# |               H(?)4|    1|
# |                  H5| 7142|
# |                  R4|   42|
# |               LL3.9|   16|
# |        Iron, IVA-an|    6|
# |        L6-melt rock|    1|
# |       Iron, IIIE-an|    1|
# |              H/L3.5|    1|
# |             L/LL5/6|    5|
# |            L3.0-3.9|    1|
# |                  CK|    3|
# |                  E5|    5|
# |                H3.2|    2|
# |             L3.8-an|    1|
# |            L3.5-3.8|    1|
# |                 EL5|    6|
# |      Mesosiderite-B|    4|
# |       Iron, IAB-sHL|   17|
# |                 CK5|   94|
# |                  CM|    4|
# |        Lodranite-an|    1|
# |          Iron, IIIE|   14|
# |            L3.7/3.8|    1|
# |                L4-6|   33|
# |                R3.8|    9|
# |     L3-melt breccia|    1|
# |       Martian (OPX)|    1|
# |Martian (basaltic...|    2|
# |                 H3 |    1|
# |                L3.7|   49|
# |            L3.3-3.6|    1|
# |             L/LL3.2|    2|
# |                LL~4|    1|
# |Martian (chassign...|    2|
# |        L(LL)3.5-3.7|    1|
# |                H3.6|   42|
# |          Iron, IAB?|    4|
# |                  R5|   20|
# |                R3-5|    6|
# |                H3.4|   16|
# |       Iron, IIAB-an|    1|
# |                 L5 |   21|
# |             L/LL3.4|    4|
# |               CO3.8|    3|
# |          Enst achon|    3|
# |      Mesosiderite-A|    2|
# |                  L6| 8285|
# |                H4/5|  428|
# |              H3.9-6|    4|
# |                L3.3|   17|
# |                 EL4|   13|
# |             H3.2-an|    3|
# |       Eucrite-pmict|  207|
# |               H/L~4|    1|
# |           Iron, IIE|   14|
# |                R3-4|    1|
# |         EH-imp melt|    6|
# |               LL3-6|    9|
# |              L3.7-6|    1|
# |                L3.9|   27|
# |         L/LL3.6/3.7|    1|
# |             H3.8-an|    2|
# |   Iron, IAB complex|   54|
# |               E3-an|    6|
# |               L(H)3|    1|
# |        Iron, IAB-MG|   84|
# |                 L~4|   10|
# |                H/L5|    7|
# |      Iron, IIIAB-an|    3|
# |                 CM1|   19|
# |                   R|    3|
# |              C2-ung|   14|
# |             L/LL5-6|    1|
# |              L(LL)6|    1|
# |        Mesosiderite|  137|
# |Lunar (feldsp. br...|   27|
# |            H(L)3-an|    1|
# |               LL5/6|   48|
# |Acapulcoite/Lodra...|    6|
# |               LL3-4|    1|
# |                L6/7|    9|
# |                  E3|  206|
# |                R3.4|    1|
# |             LL3.7-6|    1|
# |              L(LL)3|    5|
# |            H3.8/3.9|    1|
# |              C3-ung|   12|
# |           Iron, IIF|    6|
# |                H3.8|   76|
# |                H3.9|   43|
# |                R3.7|    2|
# |                 EH7|    1|
# |            L3.5-3.9|    1|
# |               LL6/7|    4|
# |              L3.9-6|    2|
# |                H-an|    4|
# |            EH3/4-an|    1|
# |              EH7-an|    1|
# |      Mesosiderite-C|    7|
# |Lunar (bas/gab brec)|    1|
# |               CR-an|    1|
# |               Iron?|    2|
# |              L3.9/4|    1|
# |                R3.9|    4|
# |           Diogenite|  241|
# |      Pallasite, PES|    4|
# |              L3.8-5|    2|
# |                CO3 |    1|
# |            L/LL3.10|    1|
# |                  E6|    9|
# |     L6-melt breccia|   10|
# |        Iron, IIIAB?|    4|
# |              L3.8-6|    9|
# |                H5-6|   63|
# |                H3.1|    2|
# |                H/L6|   11|
# |                 EL7|    1|
# |            L3.2-3.5|    1|
# |                  CB|    8|
# |                L3-7|    1|
# |             L/LL3-5|    3|
# |               L/LL3|   26|
# |         Acapulcoite|   54|
# |                L4/5|   59|
# |            L3.0-3.7|    1|
# |                L4-5|   24|
# |        LL-melt rock|    7|
# |         Ureilite-an|    4|
# |                L3.6|   48|
# |                L5-6|   41|
# |                 CH3|   21|
# |                  C2|    1|
# |                 LL6| 2043|
# |              H3.8-5|    1|
# |                H5-7|    1|
# |        Fusion crust|    4|
# |              H/L4-5|    1|
# |                R3/4|    2|
# |     H4-melt breccia|    1|
# |               LL4-6|   34|
# |               Lunar|   41|
# |              CK3-an|    3|
# |      Lunar (basalt)|   16|
# |                LL~5|    9|
# |             Angrite|   21|
# |             LL3.8-6|    3|
# |            L3.7-3.9|    1|
# |     Mesosiderite-B4|    3|
# |                 L4 |    3|
# |                 H~4|   18|
# |              CK4-an|    3|
# |          Iron, IIAB|  118|
# |                 EH6|    5|
# |               LL4/5|    5|
# |         L-melt rock|   21|
# |              H/L3-4|    1|
# |              CR2-an|    1|
# |              L/LL~4|    1|
# |            C5/6-ung|    1|
# |           LL3.1-3.5|    1|
# |                  H4| 4211|
# |                 EL6|   72|
# |     Mesosiderite-B1|    4|
# |                 CI1|    9|
# |        Diogenite-an|    3|
# |               EL3/4|    1|
# |           Pallasite|   35|
# |              LL3.00|    1|
# |Acapulcoite/lodra...|    3|
# |            H3.0-3.4|    1|
# |               LL3.3|   15|
# |              R3.5-4|    1|
# |            C3/4-ung|    1|
# |     Achondrite-prim|    9|
# |           Lodranite|   40|
# |                 CBb|    5|
# |               H3.10|    2|
# |                  L4| 1253|
# |               L/LL6|   26|
# |                 CV2|    1|
# |               L4-an|    1|
# |                  OC|   79|
# |                 H~5|  111|
# |                L3.0|    2|
# |          H-imp melt|   11|
# |                 H4 |   11|
# |               L~4-6|    1|
# |                 CO3|  335|
# |              LL7(?)|    1|
# |                 L~5|   32|
# |      H/L6-melt rock|    1|
# |               L/LL4|   20|
# |              R3.5-6|    1|
# |               LL3.1|    6|
# |                H3.7|   75|
# |               L(?)3|    2|
# |                H3.3|    7|
# |           Iron, IVA|   69|
# |      Pallasite, PMG|   38|
# |       Iron, IAB-sLM|   10|
# |                  L3|  365|
# |              L(LL)5|    1|
# |   Mesosiderite-A3/4|    1|
# |                  H?|    2|
# |                  EH|    2|
# |            L3.3-3.5|    1|
# |               H4-an|   10|
# |                H/L4|   13|
# |     Mesosiderite-B2|    5|
# |     Mesosiderite-an|    6|
# |              EH6-an|    1|
# |                 CR2|  135|
# |              LL6(?)|    1|
# |     Eucrite-Mg rich|    4|
# |             L-metal|    5|
# |                E-an|    5|
# |            L/LL(?)3|    1|
# |       Iron, IAB-sLL|   28|
# |       Chondrite-ung|   15|
# |               H(5?)|    2|
# |                 CV3|  256|
# |     H6-melt breccia|    3|
# |               H4(?)|    1|
# |             LL3.8-4|    1|
# |               L/LL5|   16|
# |                 CK3|   13|
# |               LL4/6|    1|
# |   Pallasite, PMG-an|   11|
# |               CK5/6|    6|
# |                   H|   84|
# |                 LL5| 2766|
# |                  L5| 4796|
# |               CO3.2|    8|
# |               CK4/5|   12|
# |               LL4-5|   10|
# |                LL~3|    3|
# |          Pallasite?|    1|
# +--------------------+-----+

# %%
high_iron = df.filter(df["recclass"].rlike(r"H|Iron"))
high_iron.show()
# Out:
# +-------------+----+--------+---------+--------+----+----+----------+-----------+--------------------+
# |         name|  id|nametype| recclass|mass (g)|fall|year|    reclat|    reclong|         GeoLocation|
# +-------------+----+--------+---------+--------+----+----+----------+-----------+--------------------+
# |       Aarhus|   2|   Valid|       H6|     720|Fell|1951| 56.183330|  10.233330|(56.18333, 10.23333)|
# |         Abee|   6|   Valid|      EH4|  107000|Fell|1952| 54.216670|-113.000000|  (54.21667, -113.0)|
# |     Adhi Kot| 379|   Valid|      EH4|    4239|Fell|1919| 32.100000|  71.800000|        (32.1, 71.8)|
# |         Agen| 392|   Valid|       H5|   30000|Fell|1814| 44.216670|   0.616670| (44.21667, 0.61667)|
# |     Akbarpur| 427|   Valid|       H4|    1800|Fell|1838| 29.716670|  77.950000|   (29.71667, 77.95)|
# |      Akwanga| 432|   Valid|        H|    3000|Fell|1959|  8.916670|   8.433330|  (8.91667, 8.43333)|
# |      Akyumak| 433|   Valid|Iron, IVA|   50000|Fell|1981| 39.916670|  42.816670|(39.91667, 42.81667)|
# |  Alessandria| 463|   Valid|       H5|     908|Fell|1860| 44.883330|   8.750000|    (44.88333, 8.75)|
# |Alexandrovsky| 465|   Valid|       H4|    9251|Fell|1900| 50.950000|  31.816670|   (50.95, 31.81667)|
# |      Allegan|2276|   Valid|       H5|   32000|Fell|1899| 42.533330| -85.883330|(42.53333, -85.88...|
# |Ambapur Nagla|2290|   Valid|       H5|    6400|Fell|1895| 27.666670|  78.250000|   (27.66667, 78.25)|
# |       Andura|2298|   Valid|       H6|   17900|Fell|1939| 20.883330|  76.866670|(20.88333, 76.86667)|
# |      Ankober|2304|   Valid|       H4|    6500|Fell|1942|  9.533330|  39.716670| (9.53333, 39.71667)|
# |       Anlong|2305|   Valid|       H5|    2500|Fell|1971| 25.150000| 105.183330|  (25.15, 105.18333)|
# |   Arbol Solo|2325|   Valid|       H5|     810|Fell|1954|-33.000000| -66.000000|      (-33.0, -66.0)|
# |       Archie|2329|   Valid|       H6|    5070|Fell|1932| 38.500000| -94.300000|       (38.5, -94.3)|
# |Arroyo Aguiar|2340|   Valid|       H5|    7450|Fell|1950|-31.416670| -60.666670|(-31.41667, -60.6...|
# |         Asco|2345|   Valid|       H6|      41|Fell|1805| 42.450000|   9.033330|    (42.45, 9.03333)|
# |       Assisi|2353|   Valid|       H5|    2000|Fell|1886| 43.033330|  12.550000|   (43.03333, 12.55)|
# |  Avanhandava|4905|   Valid|       H4|    9330|Fell|1952|-21.460280| -49.950830|(-21.46028, -49.9...|
# +-------------+----+--------+---------+--------+----+----+----------+-----------+--------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import when, col

is_there_iron = df.withColumn(
    "iron_level",
    when(col("recclass").rlike(r"H|Iron"), "High Iron")
    .otherwise("Not High Iron")
)

is_there_iron.select("recclass", "iron_level").show(20, False)
# Out:
# +------------+-------------+
# |recclass    |iron_level   |
# +------------+-------------+
# |L5          |Not High Iron|
# |H6          |High Iron    |
# |EH4         |High Iron    |
# |Acapulcoite |Not High Iron|
# |L6          |Not High Iron|
# |EH4         |High Iron    |
# |LL3-6       |Not High Iron|
# |H5          |High Iron    |
# |L6          |Not High Iron|
# |L           |Not High Iron|
# |Diogenite-pm|Not High Iron|
# |L6          |Not High Iron|
# |Unknown     |Not High Iron|
# |L6          |Not High Iron|
# |H4          |High Iron    |
# |H           |High Iron    |
# |Iron, IVA   |High Iron    |
# |CR2-an      |Not High Iron|
# |LL5         |Not High Iron|
# |CI1         |Not High Iron|
# +------------+-------------+
# only showing top 20 rows

# %%
counts = is_there_iron.groupBy("iron_level").count()
counts.show()
# Out:
# +-------------+-----+
# |   iron_level|count|
# +-------------+-----+
# |    High Iron|19424|
# |Not High Iron|26292|
# +-------------+-----+

# %%
pdf= counts.toPandas()

import matplotlib.pyplot as plt

plt.figure()
plt.bar(pdf["iron_level"], pdf["count"])
plt.title("High Iron vs No to Low Iron Meteorites")
plt.xlabel("Category")
plt.ylabel("Count")
plt.show()

# %%
amount_of_iron = df.withColumn(
    "iron_level",
    when(col("recclass").rlike("(?i)LL"), "Very Low")   
    .when(col("recclass").rlike("(?i)H|iron"), "High")
    .when(col("recclass").rlike("(?i)L"), "Low")
    .otherwise("Other")
)

amount_of_iron.select("recclass", "iron_level").show(20, False)
# Out:
# +------------+----------+
# |recclass    |iron_level|
# +------------+----------+
# |L5          |Low       |
# |H6          |High      |
# |EH4         |High      |
# |Acapulcoite |Low       |
# |L6          |Low       |
# |EH4         |High      |
# |LL3-6       |Very Low  |
# |H5          |High      |
# |L6          |Low       |
# |L           |Low       |
# |Diogenite-pm|Other     |
# |L6          |Low       |
# |Unknown     |Other     |
# |L6          |Low       |
# |H4          |High      |
# |H           |High      |
# |Iron, IVA   |High      |
# |CR2-an      |Other     |
# |LL5         |Very Low  |
# |CI1         |Other     |
# +------------+----------+
# only showing top 20 rows

# %%
df = df.withColumn(
    "iron_level",
    when(col("recclass").rlike("(?i)LL"), "Very Low")
    .when(col("recclass").rlike("(?i)H|iron"), "High")
    .when(col("recclass").rlike("(?i)L"), "Low")
    .otherwise("Other")
)

iron_counts = df.groupBy("iron_level").count().toPandas()

plt.figure()
plt.bar(iron_counts["iron_level"], iron_counts["count"])

plt.xlabel("Iron Level")
plt.ylabel("Count")
plt.title("Meteorite Iron Classification")

plt.show()

# %%
plt.figure()
plt.pie(pdf["count"], labels=pdf["iron_level"], autopct='%1.1f%%')
plt.title("Pie of High Iron Meteorites")
plt.show()

# %% [markdown]
# now we will divide up the globe into 4 sections to see if there is one himisphere that recives more activity. first we convert the recorded latitude and longitude to be double, then divide globe into 4 sections

# %%
df = df.withColumn("reclat", col("reclat").cast("double")) \
       .withColumn("reclong", col("reclong").cast("double")) \

# %%
df = df.withColumnRenamed("mass (g)", "mass_g")

# %%
df = df.withColumn("mass_g", col("mass_g").cast("double"))

# %%
quadrants = df.withColumn(
    "quadrant",
    when((col("reclat") >= 0) & (col("reclong") >= 0), "NE")
    .when((col("reclat") >= 0) & (col("reclong") < 0), "NW")
    .when((col("reclat") < 0) & (col("reclong") >= 0), "SE")
    .otherwise("SW")
)

# %%
quadrants.groupBy("quadrant").count().orderBy("count", ascending = False).show()
# Out:
# +--------+-----+
# |quadrant|count|
# +--------+-----+
# |      SE|21590|
# |      NE|12759|
# |      SW| 9138|
# |      NW| 2229|
# +--------+-----+

# %%
location = df.select("reclong", "reclat").dropna().limit(2000).toPandas()

# %%
plt.figure()

plt.scatter(location["reclong"], location["reclat"], alpha = 0.5)

plt.axhline(0)
plt.axvline(0)

plt.title("Meteorite Landings by Quadrants")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

plt.show()

# %%
hit_count = quadrants.groupBy("quadrant").count().toPandas()

# %%
plt.bar(hit_count["quadrant"], hit_count["count"])
plt.title("Meteorite Landings by Earth Quadrant")
plt.xlabel("Quadrant")
plt.ylabel("Number of Meteorites")
plt.show()

# %%
spark.stop()
